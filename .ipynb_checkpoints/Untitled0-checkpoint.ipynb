# %%
import urllib
from episte_fetch.pubmed_crawler import PubmedCrawler

cochrane_query = urllib.quote('"The+Cochrane+database+of+systematic+reviews"[Journal]', safe="()*+")
pm = PubmedCrawler()
documents = pm.parse_documents(strategy=cochrane_query, limit=2)
print documents
# Out:
# [{'info': {'author': ['Ratnavelu ND', 'Brown AP', 'Mallett S', 'Scholten RJ', 'Patel A', 'Founta C', 'Galaal K', 'Cross P', 'Naik R'], 'ids': {'doi': '10.1002/14651858.CD010360.pub2', 'pubmed': '26930463', 'cochrane': 'CD010360'}, 'source': 'PubMed', 'year': '2016', 'date': '2016/03/01', 'publication_type': {'pagination': 'CD010360', 'cited_medium': 'Internet', 'title': 'The Cochrane database of systematic reviews', 'ISSN': '1469-493X', 'volume': '3', 'year': '2016', 'type': 'journal'}}, 'languages': {'en': {'translation_status': 'blocked', 'abstract': "BACKGROUND: Women with suspected early-stage ovarian cancer need surgical staging which involves taking samples from areas within the abdominal cavity and retroperitoneal lymph nodes in order to inform further treatment. One potential strategy is to surgically stage all women with suspicious ovarian masses, without any histological information during surgery. This avoids incomplete staging, but puts more women at risk of potential sur
# ...
